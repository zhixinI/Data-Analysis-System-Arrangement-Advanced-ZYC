# %% [markdown]
# https://news.qq.com/zt2020/page/feiyan.htm
#
# 数据源:https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5

# %%
import requests
import json
import pandas as pd

def getData():
    url = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5'
    headers = {
        'user-agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36'
    }
    r = requests.get(url,headers)
    #r.text  json读取有这两种方式；用r.text方式传输；读取；
    res = json.loads(r.text)
    data_res = json.loads(res['data'])
    return data_res
data_dict = getData()

# %%
data_dict.keys()
# Out:
# dict_keys(['lastUpdateTime', 'chinaTotal', 'chinaAdd', 'isShowAdd', 'showAddSwitch', 'areaTree', 'chinaDayList', 'chinaDayAddList', 'dailyNewAddHistory', 'dailyHistory', 'wuhanDayList', 'articleList'])

# %% [markdown]
# 参数解析:
# lastUpdateTime : 最后的更新时间
#
# chinaTotal : 累计
# - confirm 累计确诊
# - heal 累计治疗
# - dead 累计死亡
# - nowConfirm 现有确诊
# - suspect 现有疑似
# - nowsevere 现有重症
#
# chinaAdd : 每日新增数据
# - confirm 较上日增加确诊
# - heal 较上日增加治疗
# - dead 较上日增加死亡
# - nowConfirm 较上日增加现有确诊
# - suspect 较上日增加现有疑似
# - nowsevere 较上日增加现有重症
#
# areaTree:树状形状的全球的精准数据

# %% [raw]
# pyecharts官网文档 : https://pyecharts.org/#/zh-cn/

# %%
province_list = data_dict['areaTree'][0]['children']
proList = list()
for province in province_list:
    pro_dict = dict()
    pro_dict['name'] = province['name']
    pro_dict['confirm']=province['total']['confirm']
    pro_dict['heal']=province['total']['heal']
    pro_dict['dead']=province['total']['dead']
    proList.append(pro_dict)

# %%
province_df=pd.DataFrame(proList)

# %%
province_df['nowConfirm'] = province_df.confirm - province_df.heal - province_df.dead

# %%
from pyecharts.charts import Map

#公用插件  控制图片的大小  标题颜色
from pyecharts import options as opts
from IPython.display import HTML

province_name = [str(x) for x in province_df.name]
province_confirm = [int(x) for x in province_df.confirm]
province_nowConfirm = [int(x) for x in province_df.nowConfirm]
province_heal = [int(x) for x in province_df.heal]
province_dead = [int(x) for x in province_df.dead]
#二维列表类型
gen1 = [list(z) for z in zip(province_name,province_nowConfirm)]
gen2 = [list(z) for z in zip(province_name,province_heal)]
gen3 = [list(z) for z in zip(province_name,province_dead)]
#data_pair: Sequence  zip([key],[value])

#颜色配置
pieces =[
    {'max':1,'color':'#F0F0F0'},
    {'min':1,'max':9,'color':'#FFE0E0'},
    {'min':10,'max':99,'color':'#FEC0C0'},
    {'min':100,'max':499,'color':'#FD9090'},
    {'min':500,'max':999,'color':'#FC6060'},
    {'min':1000,'max':9999,'color':'#FB3030'},
    {'min':10000,'color':'#DD0000'},
] 

# c = Map(opts.InitOpts(width='900px',height='500px'))
# c.add('全国现有确诊',gen1,'china')
# c.add('全国累计治愈',gen2,'china',is_selected=False)
# c.add('全国累计死亡',gen3,'china',is_selected=False)
# c.set_global_opts(title_opts=opts.TitleOpts(title='中国加油!武汉加油!'),\
#                  visualmap_opts=opts.VisualMapOpts(is_piecewise=True,pieces=pieces))
# c.render_notebook()
c = (
    Map(opts.InitOpts(width='900px',height='500px'))
    .add('全国现有确诊',gen1,'china')
    .add('全国累计治愈',gen2,'china',is_selected=False)
    .add('全国累计死亡',gen3,'china',is_selected=False)
    .set_global_opts(title_opts=opts.TitleOpts(title='中国加油!武汉加油!'),\
                 visualmap_opts=opts.VisualMapOpts(is_piecewise=True,pieces=pieces))
)
c.render_notebook()
# HTML('<h1>1243</h1>')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="88a3c84254f94efca16683a71ed3723d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_88a3c84254f94efca16683a71ed3723d = echarts.init(
#                     document.getElementById('88a3c84254f94efca16683a71ed3723d'), 'white', {renderer: 'canvas'});
#                 var option_88a3c84254f94efca16683a71ed3723d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5168\u56fd\u73b0\u6709\u786e\u8bca",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 5719
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 171
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 123
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 67
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 16
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 0
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         },
#         {
#             "type": "map",
#             "name": "\u5168\u56fd\u7d2f\u8ba1\u6cbb\u6108",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 58942
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 98
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 28
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 396
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1325
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 327
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 113
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1219
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 463
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 749
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 295
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 239
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 536
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 122
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 172
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 250
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 310
#                 },
#                 {

# %%
c = (
    Map(opts.InitOpts(width='900px',height='500px'))
    .add('全国现有确诊',[],'北京')
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '北京':'https://assets.pyecharts.org/assets/maps/beijing'
#         }
#     });
# </script>
#
#         <div id="93b9052156fc400eb6d2fe78230d5d26" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '北京'], function(echarts) {
#                 var chart_93b9052156fc400eb6d2fe78230d5d26 = echarts.init(
#                     document.getElementById('93b9052156fc400eb6d2fe78230d5d26'), 'white', {renderer: 'canvas'});
#                 var option_93b9052156fc400eb6d2fe78230d5d26 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5168\u56fd\u73b0\u6709\u786e\u8bca",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u5317\u4eac",
#             "data": [],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5168\u56fd\u73b0\u6709\u786e\u8bca"
#             ],
#             "selected": {
#                 "\u5168\u56fd\u73b0\u6709\u786e\u8bca": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     }
# };
#                 chart_93b9052156fc400eb6d2fe78230d5d26.setOption(option_93b9052156fc400eb6d2fe78230d5d26);
#         });
#     </script>
